# %%
import pandas as pd

# %%
emp = pd.read_excel(r"C:\Users\adars\Full_stack_data _Science_with_Ai\Full_stack_data _Science_with_Ai\Python\29_EDA_\rawdata.xlsx")

# %%
emp
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year
# 5     Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
emp.isnull()
# Out:
#     Name  Domain    Age  Location  Salary    Exp
# 0  False   False  False     False   False  False
# 1  False   False  False     False   False  False
# 2  False   False   True      True   False  False
# 3  False   False   True     False   False   True
# 4  False   False  False      True   False  False
# 5  False   False  False     False   False  False

# %%
emp .info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      str
#  1   Domain    6 non-null      str
#  2   Age       4 non-null      str
#  3   Location  4 non-null      str
#  4   Salary    6 non-null      str
#  5   Exp       5 non-null      str
# dtypes: str(6)
# memory usage: 619.0 bytes

# %%
emp.isnull().sum()
# Out:
# Name        0
# Domain      0
# Age         2
# Location    2
# Salary      0
# Exp         1
# dtype: int64

# %%
emp.dtypes
# Out:
# Name        str
# Domain      str
# Age         str
# Location    str
# Salary      str
# Exp         str
# dtype: object

# %% [markdown]
# DATA CLEANING

# %%
emp["Name"]
# Out:
# 0      Mike
# 1    Teddy^
# 2     Uma#r
# 3      Jane
# 4    Uttam*
# 5       Kim
# Name: Name, dtype: str

# %%
emp["Name"]=emp["Name"].str.replace(r"\W","",regex=True)

# %%
emp["Name"]
# Out:
# 0     Mike
# 1    Teddy
# 2     Umar
# 3     Jane
# 4    Uttam
# 5      Kim
# Name: Name, dtype: str

# %%
emp
# Out:
#     Name          Domain       Age   Location   Salary      Exp
# 0   Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy         Testing    45' yr  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3   Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam      Statistics     67-yr        NaN   30000-  5+ year
# 5    Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
emp["Age"]=emp["Age"].str.extract(r"\d+","")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 emp["Age"]=emp["Age"].str.extract(r"\d+","")
#
# File ~\.conda\envs\notebook-env\Lib\site-packages\pandas\core\strings\accessor.py:142, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     137     msg = (
#     138         f"Cannot use .str.{func_name} with values of "
#     139         f"inferred dtype '{self._inferred_dtype}'."
#     140     )
#     141     raise TypeError(msg)
# --> 142 return func(self, *args, **kwargs)
#
# File ~\.conda\envs\notebook-env\Lib\site-packages\pandas\core\strings\accessor.py:3420, in StringMethods.extract(self, pat, flags, expand)
#    3417 if not isinstance(expand, bool):
#    3418     raise ValueError("expand must be True or False")
# -> 3420 regex = re.compile(pat, flags=flags)
#    3421 if regex.groups == 0:
# ...

# %%
emp["Age"]

# %%
emp

# %%
emp["Salary"]=emp["Salary"].str.replace(r"\W","",regex=True)

# %%
emp
# Out:
#     Name          Domain       Age   Location Salary      Exp
# 0   Mike   Datascience#$  34 years     Mumbai   5000       2+
# 1  Teddy         Testing    45' yr  Bangalore  10000       <3
# 2   Umar  Dataanalyst^^#       NaN        NaN  15000   4> yrs
# 3   Jane     Ana^^lytics       NaN   Hyderbad  20000      NaN
# 4  Uttam      Statistics     67-yr        NaN  30000  5+ year
# 5    Kim             NLP      55yr      Delhi  60000      10+

# %%
emp["Domian"]=emp["Domain"].str.replace(r"\W","",regex=True)

# %%
emp
# Out:
#     Name          Domain       Age   Location Salary      Exp       Domian
# 0   Mike   Datascience#$  34 years     Mumbai   5000       2+  Datascience
# 1  Teddy         Testing    45' yr  Bangalore  10000       <3      Testing
# 2   Umar  Dataanalyst^^#       NaN        NaN  15000   4> yrs  Dataanalyst
# 3   Jane     Ana^^lytics       NaN   Hyderbad  20000      NaN    Analytics
# 4  Uttam      Statistics     67-yr        NaN  30000  5+ year   Statistics
# 5    Kim             NLP      55yr      Delhi  60000      10+          NLP

# %%
emp.head()

# %%
emp["Exp"]=emp["Exp"].str.extract(r"\d+","")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 emp["Exp"]=emp["Exp"].str.extract(r"\d+","")
#
# File ~\.conda\envs\notebook-env\Lib\site-packages\pandas\core\strings\accessor.py:142, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     137     msg = (
#     138         f"Cannot use .str.{func_name} with values of "
#     139         f"inferred dtype '{self._inferred_dtype}'."
#     140     )
#     141     raise TypeError(msg)
# --> 142 return func(self, *args, **kwargs)
#
# File ~\.conda\envs\notebook-env\Lib\site-packages\pandas\core\strings\accessor.py:3420, in StringMethods.extract(self, pat, flags, expand)
#    3417 if not isinstance(expand, bool):
#    3418     raise ValueError("expand must be True or False")
# -> 3420 regex = re.compile(pat, flags=flags)
#    3421 if regex.groups == 0:
# ...

# %%
emp
# Out:
#     Name          Domain       Age   Location   Salary      Exp
# 0   Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy         Testing    45' yr  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3   Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam      Statistics     67-yr        NaN   30000-  5+ year
# 5    Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
clean_data=emp.copy()

# %%
clean_data
# Out:
#     Name          Domain       Age   Location   Salary      Exp
# 0   Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy         Testing    45' yr  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3   Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam      Statistics     67-yr        NaN   30000-  5+ year
# 5    Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
import numpy as np

# %%
clean_data["Age"]=clean_data["Age"].fillna(np.mean(pd.to_numeric(clean_data["Age"])))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/lib.pyx:2478, in pandas._libs.lib.maybe_convert_numeric()
# -> 2478 'Could not get source, probably due dynamically evaluated source code.'
#
# ValueError: Unable to parse string "34 years"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 clean_data["Age"]=clean_data["Age"].fillna(np.mean(pd.to_numeric(clean_data["Age"])))
#
# File ~\.conda\envs\notebook-env\Lib\site-packages\pandas\core\tools\numeric.py:235, in to_numeric(arg, errors, downcast, dtype_backend)
#     233     values = ensure_object(values)
#     234     coerce_numeric = errors != "raise"
# --> 235     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     236         values,
# ...

# %%
clean_data
# Out:
#     Name          Domain       Age   Location   Salary      Exp
# 0   Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy         Testing    45' yr  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3   Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam      Statistics     67-yr        NaN   30000-  5+ year
# 5    Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
clean_data["Exp"]=clean_data["Exp"].fillna(np.mean(pd.to_numeric(clean_data["Exp"])))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/lib.pyx:2478, in pandas._libs.lib.maybe_convert_numeric()
# -> 2478 'Could not get source, probably due dynamically evaluated source code.'
#
# ValueError: Unable to parse string "2+"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 clean_data["Exp"]=clean_data["Exp"].fillna(np.mean(pd.to_numeric(clean_data["Exp"])))
#
# File ~\.conda\envs\notebook-env\Lib\site-packages\pandas\core\tools\numeric.py:235, in to_numeric(arg, errors, downcast, dtype_backend)
#     233     values = ensure_object(values)
#     234     coerce_numeric = errors != "raise"
# --> 235     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     236         values,
# ...

# %%
clean_data["Exp"]=clean_data["Exp"].fillna(np.mode(pd.to_numeric(clean_data["Exp"])))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 clean_data["Exp"]=clean_data["Exp"].fillna(np.mode(pd.to_numeric(clean_data["Exp"])))
#
# File ~\.conda\envs\notebook-env\Lib\site-packages\numpy\__init__.py:782, in __getattr__(attr)
#     775 if attr in __expired_attributes__:
#     776     raise AttributeError(
#     777         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     778         f"{__expired_attributes__[attr]}",
#     779         name=None
#     780     )
# --> 782 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
clean_data["Age"]=clean_data["Age"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 clean_data["Age"]=clean_data["Age"].astype(int)
#
# File ~\.conda\envs\notebook-env\Lib\site-packages\pandas\core\generic.py:6529, in NDFrame.astype(self, dtype, copy, errors)
#    6525             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6526
#    6527         else:
#    6528             # else, only a single dtype is given
# -> 6529             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6530             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6531             return res.__finalize__(self, method="astype")
#    6532
#
# File ~\.conda\envs\notebook-env\Lib\site-packages\pandas\core\internals\managers.py:627, in BaseBlockManager.astype(self, dtype, errors)
#     626 def astype(self, dtype, errors: str = "raise") -> Self:
# ...

# %%
clean_data
