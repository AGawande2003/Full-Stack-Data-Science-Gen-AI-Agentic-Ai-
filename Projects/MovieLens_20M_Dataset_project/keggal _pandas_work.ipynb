# %%
import pandas as pd

# %%
movies = pd.read_csv(r'C:\Users\adars\Full_stack_data _Science_with_Ai\Full_stack_data _Science_with_Ai\practice_Projects_&_Task\MovieLens_20M_Dataset_project\archive_dataset\movie.csv')

# %%
movies.shape
# Out:
# (27278, 3)

# %%
rating = pd.read_csv(r'C:\Users\adars\Full_stack_data _Science_with_Ai\Full_stack_data _Science_with_Ai\practice_Projects_&_Task\MovieLens_20M_Dataset_project\archive_dataset\rating.csv')

# %%
rating.shape
# Out:
# (20000263, 4)

# %%
tag = pd.read_csv(r'C:\Users\adars\Full_stack_data _Science_with_Ai\Full_stack_data _Science_with_Ai\practice_Projects_&_Task\MovieLens_20M_Dataset_project\archive_dataset\tag.csv')

# %%
tag.shape
# Out:
# (465564, 4)

# %%
print(movies.columns)
print(rating.columns)
print(tag.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='str')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='str')
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='str')

# %%
row_0 = tag.iloc[1]
type(row_0)
# Out:
# pandas.Series

# %%
print(row_0)
# Out:
# userId                        65
# movieId                      208
# tag                    dark hero
# timestamp    2013-05-10 01:41:18
# Name: 1, dtype: object

# %%
row_0['userId']
# Out:
# np.int64(65)

# %%
row_0['userId']
# Out:
# np.int64(65)

# %%
row_0.name
# Out:
# 1

# %%
row_0 = row_0.rename('firstRow')
row_0.name
# Out:
# 'firstRow'

# %%
tag.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
tag.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tag.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='str')

# %%
tag.iloc[ [0,11,500] ]
# Out:
#      userId  movieId                tag            timestamp
# 0        18     4141        Mark Waters  2009-04-24 18:19:40
# 11       65     1783      noir thriller  2013-05-10 01:39:43
# 500     342    55908  entirely dialogue  2012-01-31 18:41:16
