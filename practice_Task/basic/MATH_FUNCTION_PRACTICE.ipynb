# %% [markdown]
# MATH FUNCTION

# %% [markdown]
# import math as m
# print(m.sqrt(10))

# %%
import math as m 
print(m.sqrt(10))
print(m.sqrt(12))
# Out:
# 3.1622776601683795
# 3.4641016151377544

# %%
import math as m
print(m.sqrt(10))
print(m.pow(10,20))
print(m.floor(10))
print(m.ceil(10))
# Out:
# 3.1622776601683795
# 1e+20
# 10
# 10

# %% [markdown]
# m.help()

# %%
from math import  pow,sqrt,floor  #it will import only mentioned function from library
print(m.sqrt(10))
print(m.pow(10,20))
print(m.floor(10))
# Out:
# 3.1622776601683795
# 1e+20
# 10

# %%
import math
print(math.sqrt(10))
print(math.pow(10, 20))
print(math.floor(10.8))
print(math.ceil(10.2))
print(math.fabs(-25))
print(math.factorial(5))
print(math.lcm(4, 6))
print(math.fmod(10, 3))
print(math.exp(2))
# Out:
# 3.1622776601683795
# 1e+20
# 10
# 11
# 25.0
# 120
# 12
# 1.0
# 7.38905609893065
