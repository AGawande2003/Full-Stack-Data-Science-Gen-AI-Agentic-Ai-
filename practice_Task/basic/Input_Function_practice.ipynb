# %% [markdown]
# INput Function

# %%
a= input()
a
# Out:
#  5
# '5'

# %%
a= input()
b= input()
c= input()
d=a+b+c
print (d)
# Out:
#  5
#  78
#  45
# 57845

# %%
a = int(input())
b = int(input())
c = int(input())
d =a+b+c
print (d)
# Out:
#  4
#  54
#  5
# 63

# %%
a= input()
a = int(a)
b= input()
b = int(b)
c= input()
c = int(c)
d=a+b+c
print (d)
# Out:
#  5
#  5
#  6
# 16

# %%
st = str(input("enter a First Name "))
print(st)
# Out:
# enter a First Name  adarsh
# adarsh

# %%
st = input("enter a contact Number ")[2:5]
print(st)
# Out:
# enter a contact Number  1234567890
# 345

# %%
st= input("enter number")[2:5]
print(st)
# Out:
# enter number 7896543210
# 965
