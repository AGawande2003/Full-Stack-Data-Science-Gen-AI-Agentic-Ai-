# %%
pip install Streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st

st.title("My First Streamlit App")

st.write("Hello, World! 👋")
# Out:
# 2026-09-03 16:12:26.975 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-03 16:12:27.664
# ...
#   command:
#
#     streamlit run C:\Users\adars\AppData\Roaming\Python\Python314\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-09-03 16:12:27.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-03 16:12:27.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-03 16:12:27.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-03 16:12:27.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-03 16:12:27.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
