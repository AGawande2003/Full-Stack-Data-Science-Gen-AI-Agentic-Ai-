# %%
import numpy as np

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
pip install pillow
# Out:
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.2 MB 4.0 MB/s eta 0:00:02
#    ------- -------------------------------- 1.3/7.2 MB 4.2 MB/s eta 0:00:02
#    ------------- -------------------------- 2.4/7.2 MB 4.6 MB/s eta 0:00:02
#    --------------------- ------------------ 3.9/7.2 MB 5.3 MB/s eta 0:00:01
#    --------------------------------- ------ 6.0/7.2 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 5.8 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image # pythpn image library

# %%
image= Image.open(r"C:\Users\adars\Full_stack_data _Science_with_Ai\image_process\pic.jpeg")

# %%
image
# Out:
# <PIL.AvifImagePlugin.AvifImageFile image mode=RGB size=1466x1463>

# %%
type(image)
# Out:
# PIL.AvifImagePlugin.AvifImageFile

# %%
image_arr = np.asarray(image)
image_arr
# Out:
# array([[[28, 36, 21],
#         [28, 36, 21],
#         [28, 36, 21],
#         ...,
#         [40, 29, 33],
#         [41, 30, 34],
#         [41, 30, 34]],
#
#        [[27, 35, 20],
#         [28, 36, 21],
#         [28, 36, 21],
#         ...,
#         [40, 29, 33],
#         [41, 30, 34],
#         [41, 30, 34]],
#
#        [[27, 35, 20],
#         [28, 36, 21],
#         [28, 36, 21],
#         ...,
#         [40, 29, 33],
#         [41, 30, 34],
#         [41, 30, 34]],
#
#        ...,
#
#        [[50, 57, 25],
#         [53, 60, 28],
#         [53, 60, 29],
#         ...,
#         [50, 66, 29],
#         [46, 62, 25],
#         [44, 60, 23]],
#
#        [[55, 62, 28],
#         [57, 64, 32],
#         [56, 63, 32],
#         ...,
#         [47, 63, 26],
#         [45, 61, 24],
#         [43, 59, 22]],
#
#        [[56, 64, 27],
#         [58, 65, 31],
#         [57, 64, 32],
#         ...,
#         [45, 61, 24],
#         [42, 58, 21],
# ...

# %%
image_arr.shape
# Out:
# (1463, 1466, 3)

# %%
plt.imshow(image_arr)
plt.show()
